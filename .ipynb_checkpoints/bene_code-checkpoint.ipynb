# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from matplotlib.pyplot import figure

# %%
df = pd.read_csv("credit_risk_dataset.csv")
pd.set_option("display.max_rows", None, "display.max_columns", None)
df.head()
# Out:
#    person_age  person_income person_home_ownership  person_emp_length  \
# 0          22          59000                  RENT              123.0
# 1          21           9600                   OWN                5.0
# 2          25           9600              MORTGAGE                1.0
# 3          23          65500                  RENT                4.0
# 4          24          54400                  RENT                8.0
#
#   loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 0    PERSONAL          D      35000          16.02            1
# 1   EDUCATION          B       1000          11.14            0
# 2     MEDICAL          C       5500          12.87            1
# 3     MEDICAL          C      35000          15.23            1
# 4     MEDICAL          C      35000          14.27            1
#
#    loan_percent_income cb_person_default_on_file  cb_person_cred_hist_length
# 0                 0.59                         Y                           3
# ...

# %%
df.shape
# Out:
# (32581, 12)

# %%
print(df.dtypes)
# Out:
# person_age                      int64
# person_income                   int64
# person_home_ownership          object
# person_emp_length             float64
# loan_intent                    object
# loan_grade                     object
# loan_amnt                       int64
# loan_int_rate                 float64
# loan_status                     int64
# loan_percent_income           float64
# cb_person_default_on_file      object
# cb_person_cred_hist_length      int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# person_age                       0
# person_income                    0
# person_home_ownership            0
# person_emp_length              895
# loan_intent                      0
# loan_grade                       0
# loan_amnt                        0
# loan_int_rate                 3116
# loan_status                      0
# loan_percent_income              0
# cb_person_default_on_file        0
# cb_person_cred_hist_length       0
# dtype: int64

# %%
def missing_values_table(df):
    mis_val = df.isnull().sum()
    mis_val_percent = 100 * df.isnull().sum()/len(df)
    mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
    mis_val_table_ren_columns = mis_val_table.rename(
    columns = {0 : "Missing Values", 1 : "% of Total Values"})
    return mis_val_table_ren_columns
missing_values_table(df)
# Out:
#                             Missing Values  % of Total Values
# person_age                               0           0.000000
# person_income                            0           0.000000
# person_home_ownership                    0           0.000000
# person_emp_length                      895           2.747000
# loan_intent                              0           0.000000
# loan_grade                               0           0.000000
# loan_amnt                                0           0.000000
# loan_int_rate                         3116           9.563856
# loan_status                              0           0.000000
# loan_percent_income                      0           0.000000
# cb_person_default_on_file                0           0.000000
# cb_person_cred_hist_length               0           0.000000

# %%
amount_of_null_values_per_row = df.isnull().sum(axis=1)
amount_of_null_values_per_row
pd.Series(amount_of_null_values_per_row).value_counts()
# Out:
# 0    28638
# 1     3875
# 2       68
# dtype: int64

# %%
### Examine the variables
df.describe()
# Out:
#          person_age  person_income  person_emp_length     loan_amnt  \
# count  32581.000000   3.258100e+04       31686.000000  32581.000000
# mean      27.734600   6.607485e+04           4.789686   9589.371106
# std        6.348078   6.198312e+04           4.142630   6322.086646
# min       20.000000   4.000000e+03           0.000000    500.000000
# 25%       23.000000   3.850000e+04           2.000000   5000.000000
# 50%       26.000000   5.500000e+04           4.000000   8000.000000
# 75%       30.000000   7.920000e+04           7.000000  12200.000000
# max      144.000000   6.000000e+06         123.000000  35000.000000
#
#        loan_int_rate   loan_status  loan_percent_income  \
# count   29465.000000  32581.000000         32581.000000
# mean       11.011695      0.218164             0.170203
# std         3.240459      0.413006             0.106782
# min         5.420000      0.000000             0.000000
# 25%         7.900000      0.000000             0.090000
# ...

# %%
df.corr()
# Out:
#                             person_age  person_income  person_emp_length  \
# person_age                    1.000000       0.173202           0.163106
# person_income                 0.173202       1.000000           0.134268
# person_emp_length             0.163106       0.134268           1.000000
# loan_amnt                     0.050787       0.266820           0.113082
# loan_int_rate                 0.012580       0.000792          -0.056405
# loan_status                  -0.021629      -0.144449          -0.082489
# loan_percent_income          -0.042411      -0.254471          -0.054111
# cb_person_cred_hist_length    0.859133       0.117987           0.144699
#
#                             loan_amnt  loan_int_rate  loan_status  \
# person_age                   0.050787       0.012580    -0.021629
# person_income                0.266820       0.000792    -0.144449
# person_emp_length            0.113082      -0.056405    -0.082489
# ...

# %%
df.hist()
plt.show()

# %%
sns.set_theme(style="whitegrid")
ax = sns.violinplot(x=df["person_age"])

# %%
plt.hist(df['person_age'], bins=100)
plt.xlabel("person_age")
plt.ylabel("Frequency")
plt.title("Freq vs person_age")
plt.show()

# %%
df["person_age"].value_counts().sort_index()
# Out:
# 20       15
# 21     1229
# 22     3633
# 23     3889
# 24     3549
# 25     3037
# 26     2477
# 27     2138
# 28     1854
# 29     1687
# 30     1316
# 31     1142
# 32      964
# 33      856
# 34      709
# 35      620
# 36      548
# 37      478
# 38      373
# 39      302
# 40      271
# 41      241
# 42      188
# 43      164
# 44      141
# 45      108
# 46       94
# 47       94
# 48       75
# 49       49
# 50       52
# 51       39
# 52       36
# 53       30
# 54       24
# 55       20
# 56       15
# 57       15
# 58       19
# 59        5
# 60       15
# 61        9
# 62        7
# 63        3
# 64        7
# 65        9
# 66        9
# 67        1
# 69        5
# 70        7
# 73        3
# 76        1
# 78        1
# 80        1
# 84        1
# 94        1
# 123       2
# 144       3
# Name: person_age, dtype: int64

# %%
# treat age 80 and above as outliers and remove them from data

# %%
sns.set_theme(style="whitegrid")
ax = sns.violinplot(x=df["person_income"])

# %%
plt.hist(df['person_income'], bins=50)
plt.xlabel("person_income")
plt.ylabel("Frequency")
plt.title("Freq vs person_income")
plt.show()

# %%
df["person_income"].value_counts().sort_index()
# Out:
# 4000          1
# 4080          1
# 4200          2
# 4800          3
# 4888          1
# 5000          2
# 5500          1
# 6000          4
# 7000          1
# 7200          3
# 7500          1
# 7800          2
# 7904          1
# 8000          6
# 8004          1
# 8088          4
# 8280          1
# 8400          4
# 8412          1
# 8472          1
# 8500          1
# 8628          2
# 9000          2
# 9081          1
# 9192          1
# 9600         22
# 9732          1
# 9840          1
# 9900          1
# 9960          1
# 10000        20
# 10008         2
# 10080         1
# 10140         1
# 10200         4
# 10380         1
# 10400         1
# 10500         1
# 10560         2
# 10636         1
# 10668         1
# 10800        13
# 10980         1
# 11000         6
# 11029         2
# 11220         1
# 11292         1
# 11340         3
# 11389         1
# 11440         1
# 11476         1
# 11520         1
# 11688         1
# 11760         1
# 11808         1
# ...

# %%
# treat income 600k and above as outliers and remove them from data

# %%
sns.set_theme(style="whitegrid")
ax = sns.violinplot(x=df["person_emp_length"])

# %%
plt.hist(df['person_emp_length'], bins=100)
plt.xlabel("person_emp_length")
plt.ylabel("Frequency")
plt.title("Freq vs person_emp_length")
plt.show()

# %%
df["person_emp_length"].value_counts().sort_index()
# Out:
# 0.0      4105
# 1.0      2915
# 2.0      3849
# 3.0      3456
# 4.0      2874
# 5.0      2946
# 6.0      2666
# 7.0      2196
# 8.0      1687
# 9.0      1367
# 10.0      696
# 11.0      740
# 12.0      575
# 13.0      426
# 14.0      335
# 15.0      238
# 16.0      165
# 17.0      129
# 18.0      104
# 19.0       64
# 20.0       42
# 21.0       38
# 22.0       19
# 23.0       10
# 24.0       10
# 25.0        8
# 26.0        6
# 27.0        5
# 28.0        3
# 29.0        1
# 30.0        2
# 31.0        4
# 34.0        1
# 38.0        1
# 41.0        1
# 123.0       2
# Name: person_emp_length, dtype: int64

# %%
#treat employment length 50 and above as outliers and remove them from data

# %%
sns.set_theme(style="whitegrid")
ax = sns.violinplot(x=df["loan_amnt"])

# %%
plt.hist(df['loan_amnt'], bins=100)
plt.xlabel("loan_amnt")
plt.ylabel("Frequency")
plt.title("Freq vs loan_amnt")
plt.show()

# %%
sns.set_theme(style="whitegrid")
ax = sns.violinplot(x=df["loan_int_rate"])

# %%
plt.hist(df['loan_int_rate'], bins=100)
plt.xlabel("loan_int_rate")
plt.ylabel("Frequency")
plt.title("Freq vs loan_int_rate")
plt.show()

# %%
sns.set_theme(style="whitegrid")
ax = sns.violinplot(x=df["loan_percent_income"])

# %%
plt.hist(df['loan_percent_income'], bins=100)
plt.xlabel("loan_percent_income")
plt.ylabel("Frequency")
plt.title("Freq vs loan_percent_income")
plt.show()

# %%
plt.hist(df['loan_status'], bins=100)
plt.xlabel("loan_status")
plt.ylabel("Frequency")
plt.title("Freq vs loan_status")
plt.show()

# %%
plt.hist(df['cb_person_cred_hist_length'], bins=100)
plt.xlabel("cb_person_cred_hist_length")
plt.ylabel("Frequency")
plt.title("Freq vs cb_person_cred_hist_length")
plt.show()

# %%
plt.hist(df['person_home_ownership'])
plt.xlabel("person_home_ownership")
plt.ylabel("Frequency")
plt.title("Freq vs person_home_ownership")
plt.show()

# %%
plt.hist(df['loan_intent'])
plt.xlabel("loan_intent")
plt.ylabel("Frequency")
plt.title("Freq vs loan_intent")
plt.show()

# %%
plt.hist(df['loan_grade'])
plt.xlabel("loan_grade")
plt.ylabel("Frequency")
plt.title("Freq vs loan_grade")
plt.show()

# %%
plt.hist(df['cb_person_default_on_file'])
plt.xlabel("cb_person_default_on_file")
plt.ylabel("Frequency")
plt.title("Freq vs cb_person_default_on_file")
plt.show()
